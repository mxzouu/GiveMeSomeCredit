# %%
import pandas as pd 

data = pd.read_csv("train.csv")

# %%
data
# Out:
#             ID      var1  var2  var3      var4     var5  var6  var7  var8  \
# 0            1  0.766127    45     2  0.802982   9120.0    13     0     6
# 1            2  0.957151    40     0  0.121876   2600.0     4     0     0
# 2            3  0.658180    38     1  0.085113   3042.0     2     1     0
# 3            4  0.233810    30     0  0.036050   3300.0     5     0     0
# 4            5  0.907239    49     1  0.024926  63588.0     7     0     1
# ...        ...       ...   ...   ...       ...      ...   ...   ...   ...
# 104993  104994  0.080964    67     1  0.237522   9716.0    17     0     1
# 104994  104995  0.084696    70     0  0.380608   7600.0    16     0     2
# 104995  104996  0.005137    63     0  0.001613   3719.0     8     0     0
# 104996  104997  0.064271    67     0  0.103920  10305.0     7     0     1
# 104997  104998  0.977174    78     0  0.602178   7344.0    11     0     2
#
#         var9  var10  TARGET
# 0          0    2.0       1
# ...
